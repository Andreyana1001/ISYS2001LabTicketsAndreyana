# %% [markdown]
# <a href="https://colab.research.google.com/github/Andreyana1001/ISYS2001LabTicketsAndreyana/blob/main/Week_5_Andreyana_Ravina.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#creating the calculate_tip function to calculate the total bill and tip amount

def calculate_tip():
  #prompting the user to insert the bill amount and tip percentage
  bill_amount = float(input("enter the bill amount : $"))
  tip_percentage = float(input("Enter the tip percentage (e.g 18 for 18%): "))

  #formula to calculate tip amount and total bill
  tip_amount = bill_amount *(tip_percentage/100)
  total_bill = bill_amount + tip_amount

#Displaying the tip amount and total bill
  print(f"Tip amount: $ {tip_amount: .2f}")    #Display tip_amount to two decimal places
  print(f"Total amount: $ {total_bill: .2f}")  #Display total_bill to two decimal places

#Calling the functioncalculate_tip()
calculate_tip()
# Out:
# enter the bill amount : $5000
# Enter the tip percentage (e.g 18 for 18%): 10
# Tip amount: $  500.00
# Total amount: $  5500.00

# %%
def budget_recommendation(monthly_income, current_expenses, savings_goal=0.20):
    recommended_savings = monthly_income * savings_goal
    available_for_additional = monthly_income - current_expenses - recommended_savings

    print(f"Monthly income : ${monthly_income: 2f}")
    print(f"Current expenses: ${current_expenses: 2f}")
    print(f"Recommended savings ({savings_goal*100:.0f}%): ${recommended_savings:.2f}")
    print(f"Available for additional expenses: ${available_for_additional:.2f}")
    if available_for_additional < 0:
        print("Warning: You're overspending your budget!")
    elif available_for_additional < 100:
        print("Budget is tight. Consider reducing expenses.")
    else:
      print("Good budget balance!")
budget_recommendation (3000,2200) #uses default 20% savings
  #budget_recommendation(3000,2200,0.15) #Custom 15% savings goal
# Out:
# Monthly income : $ 3000.000000
# Current expenses: $ 2200.000000
# Recommended savings (20%): $600.00
# Available for additional expenses: $200.00
# Good budget balance!

# %%
#The return Statement
#No return

def calculate_roi(initial_investment, final_value):
  profit= final_value - initial_investment
  roi= (profit/initial_investment) * 100
  #print(f"ROI is {eoi:.1f}%")

value = calculate_roi(1000, 1200)
print(value)

#output is displayed but nothing is saved
# Out:
# None

# %%
#return

def calculate_roi(initial_investment, final_value):
    profit= final_value - initial_investment
    roi= (profit/initial_investment) * 100
    return roi



result= calculate_roi(1000, 1200)
print(f"ROI is {result:.1f}%")
# Out:
# ROI is 20.0%

# %%
#AVERAGE
def calculate_roi(initial_investment, final_value):
    profit= final_value - initial_investment
    roi= (profit/initial_investment) * 100
    return roi

roi1 = calculate_roi(1000, 1200)
roi2= calculate_roi(2000, 2600)
average = (roi1 + roi2) / 2
print(average)
# Out:
# 25.0

# %%
def calculate_monthly_payment(principal,annual_rate, months):
    monthly_rate = annual_rate / 12
    payment = principal * (monthly_rate * (1 + monthly_rate)** months) / ((1 + monthly_rate)**months - 1)
    return payment #Use the returned value in other calculations

    #Calling Function and calculating monthly payment and remaining income

loan_payment = calculate_monthly_payment(25000, 0.05, 60)
monthly_income = 4000
remaining_income = monthly_income - loan_payment
print(f"Loan payment: ${loan_payment:.2f}")
print(f"remaining income: ${remaining_income:.2f}")
# Out:
# Loan payment: $471.78
# remaining income: $3528.22

# %%
loan_payment = calculate_monthly_payment(300900, 0.06, 90)
monthly_income = 8000
remaining_income = monthly_income - loan_payment
print(f"Loan payment: ${loan_payment:.2f}")
print(f"remaining income: ${remaining_income:.2f}")
# Out:
# Loan payment: $4160.02
# remaining income: $3839.98

# %%
from datetime import datetime

#Get the current date and time
current_time = datetime.now()
print("Current date and time:", current_time)
# Out:
# Current date and time: 2026-03-18 12:34:39.647497

# %%
from datetime import datetime
current_date = datetime.now().date()
print("Current date:", current_date)
# Out:
# Current date: 2026-03-18

# %%
from datetime import time
current_time = datetime.now().time()
print("Current time:", current_time)
# Out:
# Current time: 12:39:00.462684
